# %% [markdown]
# <a href="https://colab.research.google.com/github/L-droid815/Adivina-el-numero.github.io/blob/main/LuisAlejandro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matploitlip as mp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9577/3119544281.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 import matploitlip as mp
#
# ModuleNotFoundError: No module named 'matploitlip'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
